# %% [markdown]
# # Importing all the necessary libraries

# %%
pip install modin[all]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting modin[all]
#   Obtaining dependency information for modin[all] from https://files.pythonhosted.org/packages/fd/0e/c6c1c28140e2492b01cf7e0eba712d8c9828e27b98027d48317e33e77d93/modin-0.26.1-py3-none-any.whl.metadata
#   Using cached modin-0.26.1-py3-none-any.whl.metadata (17 kB)
# Collecting pandas<2.2,>=2.1 (from modin[all])
#   Obtaining dependency information for pandas<2.2,>=2.1 from https://files.pythonhosted.org/packages/f8/8c/9ad173c5cd2c7178c84075c02ec37b5d1d53fb1d015f51ea3e623ea9c31c/pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: packaging>=21.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from modin[all]) (23.1)
# Requirement already satisfied: numpy>=1.22.4 in ./.local/lib/python3.11/site-packages (from modin[all]) (1.26.4)
# Collecting fsspec>=2022.05.0 (from modin[all])
#   Obtaining dependency information for fsspec>=2022.05.0 from https://files.pythonhosted.org/packages/ad/30/2281c062222dc39328843bd1ddd30ff3005ef8e30b2fd09c4d2792766061/fsspec-2024.2.0-py3-none-any.whl.metadata
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: psutil>=5.8.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from modin[all]) (5.9.5)
# Collecting dask>=2.22.0 (from modin[all])
#   Obtaining dependency information for dask>=2.22.0 from https://files.pythonhosted.org/packages/95/a5/2ab515c77b441795d7154c57ba224fa41c827ba1e291bbbbcc12f8ac050b/dask-2024.2.0-py3-none-any.whl.metadata
#   Downloading dask-2024.2.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting distributed>=2.22.0 (from modin[all])
#   Obtaining dependency information for distributed>=2.22.0 from https://files.pythonhosted.org/packages/e3/a0/12cc57de8f6015bfbfbfd83a6562251f60ba7cc2de5704ccc06d7761079b/distributed-2024.2.0-py3-none-any.whl.metadata
#   Downloading distributed-2024.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ray[default]!=2.5.0,>=1.13.0 (from modin[all])
#   Obtaining dependency information for ray[default]!=2.5.0,>=1.13.0 from https://files.pythonhosted.org/packages/3c/50/da0c3735f5fc1ad97af92b11993ed375b464139ac93352a5cb0a23e31293/ray-2.9.2-cp311-cp311-manylinux2014_x86_64.whl.metadata
#   Using cached ray-2.9.2-cp311-cp311-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting pyarrow>=7.0.0 (from modin[all])
#   Obtaining dependency information for pyarrow>=7.0.0 from https://files.pythonhosted.org/packages/85/55/636f006d963ddf77270fd294163e149b0719aaaf794de0d023aee88f6335/pyarrow-15.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Using cached pyarrow-15.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pydantic<2 (from modin[all])
#   Obtaining dependency information for pydantic<2 from https://files.pythonhosted.org/packages/1d/99/128bae7beff5cd5636f41a49bc1f58e5aaeb186d5f674ae4b2eb88608127/pydantic-1.10.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached pydantic-1.10.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (150 kB)
# Collecting modin-spreadsheet>=0.1.0 (from modin[all])
#   Using cached modin_spreadsheet-0.1.2-py2.py3-none-any.whl (1.8 MB)
# Collecting click>=8.1 (from dask>=2.22.0->modin[all])
#   Obtaining dependency information for click>=8.1 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle>=1.5.0 (from dask>=2.22.0->modin[all])
#   Obtaining dependency information for cloudpickle>=1.5.0 from https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl.metadata
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting partd>=1.2.0 (from dask>=2.22.0->modin[all])
#   Obtaining dependency information for partd>=1.2.0 from https://files.pythonhosted.org/packages/11/8a/b7a58e208b144a7315208a0dd627e23f5f50b47fa89c2924bb2e9238ecfb/partd-1.4.1-py3-none-any.whl.metadata
#   Using cached partd-1.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from dask>=2.22.0->modin[all]) (6.0.1)
# Collecting toolz>=0.10.0 (from dask>=2.22.0->modin[all])
#   Obtaining dependency information for toolz>=0.10.0 from https://files.pythonhosted.org/packages/b7/8a/d82202c9f89eab30f9fc05380daae87d617e2ad11571ab23d7c13a29bb54/toolz-0.12.1-py3-none-any.whl.metadata
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting importlib-metadata>=4.13.0 (from dask>=2.22.0->modin[all])
#   Obtaining dependency information for importlib-metadata>=4.13.0 from https://files.pythonhosted.org/packages/c0/8b/d8427f023c081a8303e6ac7209c16e6878f2765d5b59667f3903fbcfd365/importlib_metadata-7.0.1-py3-none-any.whl.metadata
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jinja2>=2.10.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from distributed>=2.22.0->modin[all]) (3.1.2)
# Collecting locket>=1.0.0 (from distributed>=2.22.0->modin[all])
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msgpack>=1.0.0 (from distributed>=2.22.0->modin[all])
#   Obtaining dependency information for msgpack>=1.0.0 from https://files.pythonhosted.org/packages/df/09/dee50913ba5cc047f7fd7162f09453a676e7935c84b3bf3a398e12108677/msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting sortedcontainers>=2.0.5 (from distributed>=2.22.0->modin[all])
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting tblib>=1.6.0 (from distributed>=2.22.0->modin[all])
#   Obtaining dependency information for tblib>=1.6.0 from https://files.pythonhosted.org/packages/9b/87/ce70db7cae60e67851eb94e1a2127d4abb573d3866d2efd302ceb0d4d2a5/tblib-3.0.0-py3-none-any.whl.metadata
#   Using cached tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.0.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from distributed>=2.22.0->modin[all]) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from distributed>=2.22.0->modin[all]) (2.0.5)
# Collecting zict>=3.0.0 (from distributed>=2.22.0->modin[all])
#   Using cached zict-3.0.0-py2.py3-none-any.whl (43 kB)
# Collecting jupyter>=1.0.0 (from modin-spreadsheet>=0.1.0->modin[all])
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: notebook>=6.0.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from modin-spreadsheet>=0.1.0->modin[all]) (7.0.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from modin-spreadsheet>=0.1.0->modin[all]) (8.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from pandas<2.2,>=2.1->modin[all]) (2.8.2)
# Collecting pytz>=2020.1 (from pandas<2.2,>=2.1->modin[all])
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas<2.2,>=2.1->modin[all])
#   Obtaining dependency information for tzdata>=2022.1 from https://files.pythonhosted.org/packages/a3/fb/52b62131e21b24ee297e4e95ed41eba29647dad0e0051a92bb66b43c70ff/tzdata-2023.4-py2.py3-none-any.whl.metadata
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from pydantic<2->modin[all]) (4.8.0)
# Collecting filelock (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: jsonschema in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ray[default]!=2.5.0,>=1.13.0->modin[all]) (4.19.1)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for protobuf!=3.19.5,>=3.15.3 from https://files.pythonhosted.org/packages/81/9e/63501b8d5b4e40c7260049836bd15ec3270c936e83bc57b85e4603cc212c/protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Using cached protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting aiosignal (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for frozenlist from https://files.pythonhosted.org/packages/b3/c9/0bc5ee7e1f5cc7358ab67da0b7dfe60fbd05c254cea5c6108e7d1ae28c63/frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ray[default]!=2.5.0,>=1.13.0->modin[all]) (2.31.0)
# Collecting aiohttp>=3.7 (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for aiohttp>=3.7 from https://files.pythonhosted.org/packages/84/bb/74c9f32e1a76fab04b54ed6cd4b0dc4a07bd9dc6f3bb37f630149a9c3068/aiohttp-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached aiohttp-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting aiohttp-cors (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for colorful from https://files.pythonhosted.org/packages/b3/61/39e7db0cb326c9c8f6a49fad4fc9c2f1241f05a4e10f0643fc31ce26a7e0/colorful-0.5.6-py2.py3-none-any.whl.metadata
#   Using cached colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Collecting gpustat>=1.0.0 (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached gpustat-1.1.1.tar.gz (98 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting opencensus (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for opencensus from https://files.pythonhosted.org/packages/b5/ed/9fbdeb23a09e430d87b7d72d430484b88184633dc50f6bfb792354b6f661/opencensus-0.11.4-py2.py3-none-any.whl.metadata
#   Using cached opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ray[default]!=2.5.0,>=1.13.0->modin[all]) (0.17.1)
# Collecting smart-open (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for smart-open from https://files.pythonhosted.org/packages/fc/d9/d97f1db64b09278aba64e8c81b5d322d436132df5741c518f3823824fae0/smart_open-6.4.0-py3-none-any.whl.metadata
#   Using cached smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for virtualenv!=20.21.1,>=20.0.24 from https://files.pythonhosted.org/packages/83/22/54b1180756d2d6194bcafb7425d437c3034c4bff92129c3e1e633079e2c4/virtualenv-20.25.0-py3-none-any.whl.metadata
#   Using cached virtualenv-20.25.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting grpcio>=1.42.0 (from ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for grpcio>=1.42.0 from https://files.pythonhosted.org/packages/b8/c7/44201b27a9be0af7f997881904ce878a09a7fe95fc2e273d2f92b7b5b373/grpcio-1.60.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached grpcio-1.60.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0->modin[all]) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for multidict<7.0,>=4.5 from https://files.pythonhosted.org/packages/52/ec/be54a3ad110f386d5bd7a9a42a4ff36b3cd723ebe597f41073a73ffa16b8/multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for yarl<2.0,>=1.0 from https://files.pythonhosted.org/packages/9f/ea/94ad7d8299df89844e666e4aa8a0e9b88e02416cd6a7dd97969e9eae5212/yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for nvidia-ml-py>=11.450.129 from https://files.pythonhosted.org/packages/a8/10/35b88b64d76aac88ae6b39208827ac0e2a4a2d78f3f2159882efefcad7fd/nvidia_ml_py-12.535.133-py3-none-any.whl.metadata
#   Using cached nvidia_ml_py-12.535.133-py3-none-any.whl.metadata (8.6 kB)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=4.13.0->dask>=2.22.0->modin[all])
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl.metadata
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: comm>=0.1.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.10.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jinja2>=2.10.3->distributed>=2.22.0->modin[all]) (2.1.3)
# Collecting qtconsole (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Obtaining dependency information for qtconsole from https://files.pythonhosted.org/packages/d5/21/0887c50fa5bca7bfde29f65999a6ac234617f2a007b6b387aa4dc0ca36a8/qtconsole-5.5.1-py3-none-any.whl.metadata
#   Using cached qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: nbconvert in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (7.8.0)
# Requirement already satisfied: ipykernel in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.25.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.7.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (4.0.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.2.3)
# Requirement already satisfied: six>=1.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<2.2,>=2.1->modin[all]) (1.16.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for distlib<1,>=0.3.7 from https://files.pythonhosted.org/packages/8e/41/9307e4f5f9976bc8b7fea0b66367734e8faf3ec84bc0d412d8cfabbb66cd/distlib-0.3.8-py2.py3-none-any.whl.metadata
#   Using cached distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]!=2.5.0,>=1.13.0->modin[all]) (3.10.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (0.10.3)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for google-api-core<3.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/60/51/2054dfc08dda9a3add0d715cee98d6f8211c99bd6e5bff0ff1bdd3cf3384/google_api_core-2.17.0-py3-none-any.whl.metadata
#   Downloading google_api_core-2.17.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests->ray[default]!=2.5.0,>=1.13.0->modin[all]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests->ray[default]!=2.5.0,>=1.13.0->modin[all]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests->ray[default]!=2.5.0,>=1.13.0->modin[all]) (2023.7.22)
# Requirement already satisfied: wcwidth>=0.1.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]!=2.5.0,>=1.13.0->modin[all]) (0.2.6)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/f0/43/c9d8f75ddf08e2a0a27db243c13a700c3cc7ec615b545b697cf6f715ad92/googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata
#   Using cached googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for google-auth<3.0.dev0,>=2.14.1 from https://files.pythonhosted.org/packages/82/41/7fb855444cead5b2213e053447ce3a0b7bf2c3529c443e0cf75b2f13b405/google_auth-2.27.0-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: backcall in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: decorator in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.6)
# Requirement already satisfied: pickleshare in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.16.1)
# Requirement already satisfied: stack-data in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.8.0)
# Requirement already satisfied: anyio>=3.1.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (4.0.0)
# Requirement already satisfied: argon2-cffi in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.9.2)
# Requirement already satisfied: overrides in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (7.4.0)
# Requirement already satisfied: pyzmq>=24 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.17.1)
# Requirement already satisfied: websocket-client in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.9.14)
# Requirement already satisfied: beautifulsoup4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.0.0)
# Requirement already satisfied: defusedxml in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.0)
# Requirement already satisfied: tinycss2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.8.0)
# Requirement already satisfied: nest-asyncio in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.8)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Obtaining dependency information for qtpy>=2.4.0 from https://files.pythonhosted.org/packages/7e/a9/2146d5117ad8a81185331e0809a6b48933c10171f5bac253c6df9fce991c/QtPy-2.4.1-py3-none-any.whl.metadata
#   Using cached QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sniffio>=1.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.3.0)
# Requirement already satisfied: webencodings in /srv/jupyter/python-venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.5.1)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.1.1)
# Requirement already satisfied: fastjsonschema in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /srv/jupyter/python-venv/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.4.0)
# Requirement already satisfied: pure-eval in /srv/jupyter/python-venv/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.2)
# Requirement already satisfied: fqdn in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (1.5.1)
# Requirement already satisfied: isoduration in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (2.4)
# Requirement already satisfied: uri-template in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (1.13)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0->modin[all])
#   Obtaining dependency information for pyasn1<0.6.0,>=0.4.6 from https://files.pythonhosted.org/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl.metadata
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.15.1)
# Requirement already satisfied: pycparser in /srv/jupyter/python-venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from isoduration->jsonschema->ray[default]!=2.5.0,>=1.13.0->modin[all]) (1.2.3)
# ERROR: Will not install to the user site because it will lack sys.path precedence to pydantic in /srv/jupyter/python-venv/lib/python3.11/site-packages
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install intel-tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting intel-tensorflow
#   Obtaining dependency information for intel-tensorflow from https://files.pythonhosted.org/packages/a5/8f/a3691a7359fd0795ac5e78f0bf448f69a2defe2e87157c8171bc8a0f64b7/intel_tensorflow-2.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading intel_tensorflow-2.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from intel-tensorflow)
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from intel-tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from intel-tensorflow)
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from intel-tensorflow)
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from intel-tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from intel-tensorflow)
#   Obtaining dependency information for h5py>=2.9.0 from https://files.pythonhosted.org/packages/1e/e9/61d7338e503d63d2ce733373fa86256614f579b173cf3d0571d4f46cb561/h5py-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading h5py-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from intel-tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/ea/df/55525e489c43f9dbb6c8ea27d8a567b3dcd18a22f3c45483055f5ca6611d/libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes==0.2.0 (from intel-tensorflow)
#   Obtaining dependency information for ml-dtypes==0.2.0 from https://files.pythonhosted.org/packages/87/91/d57c2d22e4801edeb7f3e7939214c0ea8a28c6e16f85208c2df2145e0213/ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in ./.local/lib/python3.11/site-packages (from intel-tensorflow) (1.26.4)
# Collecting opt-einsum>=2.3.2 (from intel-tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in /srv/jupyter/python-venv/lib/python3.11/site-packages (from intel-tensorflow) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from intel-tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/81/9e/63501b8d5b4e40c7260049836bd15ec3270c936e83bc57b85e4603cc212c/protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Using cached protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /srv/jupyter/python-venv/lib/python3.11/site-packages (from intel-tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from intel-tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from intel-tensorflow)
#   Obtaining dependency information for termcolor>=1.1.0 from https://files.pythonhosted.org/packages/d9/5f/8c716e47b3a50cbd7c146f45881e11d9414def768b7cd9c5e6650ec2a80a/termcolor-2.4.0-py3-none-any.whl.metadata
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from intel-tensorflow) (4.8.0)
# Collecting wrapt<1.15,>=1.11.0 (from intel-tensorflow)
#   Obtaining dependency information for wrapt<1.15,>=1.11.0 from https://files.pythonhosted.org/packages/7f/1b/e0439eec0db6520968c751bc7e12480bb80bb8d939190e0e55ed762f3c7a/wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from intel-tensorflow)
#   Obtaining dependency information for tensorflow-io-gcs-filesystem>=0.23.1 from https://files.pythonhosted.org/packages/44/66/10773d9ea847ba0ae5c36478333d92c6dae3396205bf18091910f63f3ee9/tensorflow_io_gcs_filesystem-0.36.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from intel-tensorflow)
#   Obtaining dependency information for grpcio<2.0,>=1.24.3 from https://files.pythonhosted.org/packages/b8/c7/44201b27a9be0af7f997881904ce878a09a7fe95fc2e273d2f92b7b5b373/grpcio-1.60.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached grpcio-1.60.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.15,>=2.14 (from intel-tensorflow)
#   Obtaining dependency information for tensorboard<2.15,>=2.14 from https://files.pythonhosted.org/packages/73/a2/66ed644f6ed1562e0285fcd959af17670ea313c8f331c46f79ee77187eb9/tensorboard-2.14.1-py3-none-any.whl.metadata
#   Downloading tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from intel-tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.15,>=2.14.0 from https://files.pythonhosted.org/packages/d1/da/4f264c196325bb6e37a6285caec5b12a03def489b57cc1fdac02bb6272cd/tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.15,>=2.14.0 (from intel-tensorflow)
#   Obtaining dependency information for keras<2.15,>=2.14.0 from https://files.pythonhosted.org/packages/fe/58/34d4d8f1aa11120c2d36d7ad27d0526164b1a8ae45990a2fede31d0e59bf/keras-2.14.0-py3-none-any.whl.metadata
#   Downloading keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->intel-tensorflow)
#   Obtaining dependency information for wheel<1.0,>=0.23.0 from https://files.pythonhosted.org/packages/c7/c3/55076fc728723ef927521abaa1955213d094933dc36d4a2008d5101e1af5/wheel-0.42.0-py3-none-any.whl.metadata
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.15,>=2.14->intel-tensorflow)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/82/41/7fb855444cead5b2213e053447ce3a0b7bf2c3529c443e0cf75b2f13b405/google_auth-2.27.0-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->intel-tensorflow)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.15,>=2.14->intel-tensorflow)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/42/f4/f0031854de10a0bc7821ef9fca0b92ca0d7aa6fbfbf504c5473ba825e49c/Markdown-3.5.2-py3-none-any.whl.metadata
#   Downloading Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->intel-tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.15,>=2.14->intel-tensorflow)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/73/c6/825dab04195756cf8ff2e12698f22513b3db2f64925bdd41671bfb33aaa5/tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.15,>=2.14->intel-tensorflow)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/c3/fc/254c3e9b5feb89ff5b9076a23218dafbc99c96ac5941e900b71206e6313b/werkzeug-3.0.1-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->intel-tensorflow)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->intel-tensorflow)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->intel-tensorflow)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->intel-tensorflow)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->intel-tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->intel-tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->intel-tensorflow) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->intel-tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->intel-tensorflow) (2.1.3)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->intel-tensorflow)
#   Obtaining dependency information for pyasn1<0.6.0,>=0.4.6 from https://files.pythonhosted.org/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl.metadata
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->intel-tensorflow) (3.2.2)
# Downloading intel_tensorflow-2.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (249.9 MB)
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/249.9 MB 119.8 kB/s eta 0:25:46^C
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/249.9 MB 119.8 kB/s eta 0:25:46
# ERROR: Operation cancelled by user
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn-intelex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn-intelex
#   Obtaining dependency information for scikit-learn-intelex from https://files.pythonhosted.org/packages/70/2e/8a5b5ec54d91114fe3186480eff1d2db3a7c391dcde5b50324d474257de8/scikit_learn_intelex-2024.1.0-py311-none-manylinux1_x86_64.whl.metadata
#   Downloading scikit_learn_intelex-2024.1.0-py311-none-manylinux1_x86_64.whl.metadata (12 kB)
# Collecting daal4py==2024.1.0 (from scikit-learn-intelex)
#   Obtaining dependency information for daal4py==2024.1.0 from https://files.pythonhosted.org/packages/65/a0/8426a2d378ec3bdbf4efc9cc93723ab0f9635a02e01f0210dfb0cca78b5c/daal4py-2024.1.0-py311-none-manylinux1_x86_64.whl.metadata
#   Downloading daal4py-2024.1.0-py311-none-manylinux1_x86_64.whl.metadata (7.4 kB)
# Collecting scikit-learn>=0.22 (from scikit-learn-intelex)
#   Obtaining dependency information for scikit-learn>=0.22 from https://files.pythonhosted.org/packages/5b/be/208f17ce87a5e55094b0e8ffd55b06919ab9b56e7e4ce2a64cd9095ec5d2/scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting daal==2024.1.0 (from daal4py==2024.1.0->scikit-learn-intelex)
#   Obtaining dependency information for daal==2024.1.0 from https://files.pythonhosted.org/packages/d0/8b/2e9e132204baffd13c3c81672eb36e9b3fbb20d6433ff0a9b520dd14432a/daal-2024.1.0-py2.py3-none-manylinux1_x86_64.whl.metadata
#   Downloading daal-2024.1.0-py2.py3-none-manylinux1_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: numpy>=1.19 in ./.local/lib/python3.11/site-packages (from daal4py==2024.1.0->scikit-learn-intelex) (1.26.4)
# Collecting tbb==2021.* (from daal==2024.1.0->daal4py==2024.1.0->scikit-learn-intelex)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/31/fc/eeb2ab19f26e608bda910350b6f0a06e8dd1b472049b175ca36df93c81ff/tbb-2021.11.0-py2.py3-none-manylinux1_x86_64.whl.metadata
#   Downloading tbb-2021.11.0-py2.py3-none-manylinux1_x86_64.whl.metadata (1.0 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=0.22->scikit-learn-intelex)
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/d4/b8/7169935f9a2ea9e274ad8c21d6133d492079e6ebc3fc69a915c2375616b0/scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 195.6 kB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn>=0.22->scikit-learn-intelex)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.22->scikit-learn-intelex)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn_intelex-2024.1.0-py311-none-manylinux1_x86_64.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 317.2 kB/s eta 0:00:00a 0:00:01
# Downloading daal4py-2024.1.0-py311-none-manylinux1_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 120.2 kB/s eta 0:00:0000:010:03
# Using cached daal-2024.1.0-py2.py3-none-manylinux1_x86_64.whl (75.3 MB)
# Using cached tbb-2021.11.0-py2.py3-none-manylinux1_x86_64.whl (5.4 MB)
# Downloading scikit_learn-1.4.0-1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 9.1/12.1 MB 175.5 kB/s eta 0:00:18

# %%
import modin.pandas as pd
import numpy as np

import warnings

import matplotlib.pyplot as plt
# %matplotlib inline
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import plot
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

import sklearn.metrics as metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Dropout
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Data Preprocessing

# %%
#Load the dataset
stock = pd.read_csv("/content/msft-daily-max.csv")
stock.head()
# Out:
#         Date      Open      High       Low     Close      Volume  Adj Close
# 0  3/13/1986  0.088542  0.101563  0.088542  0.097222  1031788800   0.060524
# 1  3/14/1986  0.097222  0.102431  0.097222  0.100694   308160000   0.062686
# 2  3/17/1986  0.100694  0.103299  0.100694  0.102431   133171200   0.063767
# 3  3/18/1986  0.102431  0.103299  0.098958  0.099826    67766400   0.062145
# 4  3/19/1986  0.099826  0.100694  0.097222  0.098090    47894400   0.061065

# %%
from datetime import datetime
stock['Date'] = pd.to_datetime(stock['Date'])
stock = stock.set_index('Date')

# %%
stock.head()
# Out:
#                 Open      High       Low     Close      Volume  Adj Close
# Date
# 1986-03-13  0.088542  0.101563  0.088542  0.097222  1031788800   0.060524
# 1986-03-14  0.097222  0.102431  0.097222  0.100694   308160000   0.062686
# 1986-03-17  0.100694  0.103299  0.100694  0.102431   133171200   0.063767
# 1986-03-18  0.102431  0.103299  0.098958  0.099826    67766400   0.062145
# 1986-03-19  0.099826  0.100694  0.097222  0.098090    47894400   0.061065

# %%
# Box plot to check whether outliers are present or not

stock[['Open','High','Low','Close','Adj Close',]].plot(kind='box')
stock[['Volume']].plot(kind='box')
# Out:
# <Axes: >

# %%
q1, q3 = np.percentile(stock['Open'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock[(stock['Open'] >= lower_bound)
                & (stock['Open'] <= upper_bound)]

q1, q3 = np.percentile(stock['High'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock[(stock['High'] >= lower_bound)
                & (stock['High'] <= upper_bound)]

q1, q3 = np.percentile(stock['Low'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock[(stock['Low'] >= lower_bound)
                & (stock['Low'] <= upper_bound)]

q1, q3 = np.percentile(stock['Close'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock[(stock['Close'] >= lower_bound)
                & (stock['Close'] <= upper_bound)]

q1, q3 = np.percentile(stock['Adj Close'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock[(stock['Adj Close'] >= lower_bound)
                & (stock['Adj Close'] <= upper_bound)]

q1, q3 = np.percentile(stock['Volume'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock[(stock['Volume'] >= lower_bound)
                & (stock['Volume'] <= upper_bound)]

# %%
train = clean_data.loc[clean_data.index < '01-02-2016']
test = clean_data.loc[clean_data.index >= '01-02-2016']

# Plot the data
fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-02-2016', color='black', linestyle='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
clean_data['Date']=clean_data.index
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
clean_data["year"] = clean_data["Date"].dt.year
clean_data["month"] = clean_data["Date"].dt.month
clean_data["day_of_week"] = clean_data["Date"].dt.dayofweek
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
clean_data = clean_data.drop(['Date'], axis=1)

# %%
clean_data.head()
# Out:
#                 Open      High       Low     Close    Volume  Adj Close  year  \
# Date
# 1986-03-18  0.102431  0.103299  0.098958  0.099826  67766400   0.062145  1986
# 1986-03-19  0.099826  0.100694  0.097222  0.098090  47894400   0.061065  1986
# 1986-03-20  0.098090  0.098090  0.094618  0.095486  58435200   0.059444  1986
# 1986-03-21  0.095486  0.097222  0.091146  0.092882  59990400   0.057823  1986
# 1986-03-24  0.092882  0.092882  0.089410  0.090278  65289600   0.056201  1986
#
#             month  day_of_week
# Date
# 1986-03-18      3            1
# 1986-03-19      3            2
# 1986-03-20      3            3
# 1986-03-21      3            4
# 1986-03-24      3            0

# %%
plt.figure(figsize = (18,9))
plt.plot(range(clean_data.shape[0]),(clean_data['Low']+clean_data['High'])/2.0)
plt.xticks(range(0,clean_data.shape[0],500),clean_data['year'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
X=clean_data.drop('Adj Close',axis=1)
y=clean_data['Adj Close']

# %% [markdown]
# # Regression Models

# %%
#splitting test and train data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=50)

# %% [markdown]
# Linear Regression

# %%
lreg = LinearRegression()

# Model Training
lreg.fit(X_train,y_train)

# Model Prediction
y_pred_lreg = lreg.predict(X_test)

# Model Performance
mae = metrics.mean_absolute_error(y_test, y_pred_lreg)
mse = metrics.mean_squared_error(y_test, y_pred_lreg)
rmse = np.sqrt(mse) # or mse**(0.5)
r2 = metrics.r2_score(y_test, y_pred_lreg)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 2.7186124481271396
# MSE: 13.377975666215852
# RMSE: 3.6575915116666393
# R-Squared: 0.9975529325779955

# %%
# Plotting
plt.scatter(y_test, y_pred_lreg)
plt.xlabel('y_test')
plt.ylabel('y_pred_lreg')
plt.title('Actual Values vs Predicted Values')
plt.show()

# %% [markdown]
# SVM

# %%
clf = svm.SVR()

# Model Training
clf.fit(X_train,y_train)

# Model Prediction
y_pred_svm = clf.predict(X_test)

# Model Performance
mae = metrics.mean_absolute_error(y_test, y_pred_svm)
mse = metrics.mean_squared_error(y_test, y_pred_svm)
rmse = mse**(0.5)
r2 = metrics.r2_score(y_test, y_pred_svm)

print("Results:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results:
# MAE: 34.915659421966176
# MSE: 5070.340537831026
# RMSE: 71.20632372079763
# R-Squared: 0.07254539414896644

# %%
# Plotting
plt.scatter(y_test, y_pred_svm)
plt.xlabel('y_test')
plt.ylabel('y_pred_svm')
plt.title('Actual Values vs Predicted Values')
plt.show()

# %% [markdown]
# Decision Tree

# %%
dTree = DecisionTreeRegressor()

# Model Training
dTree.fit(X_train,y_train)

# Model Prediction
y_pred_dTree = dTree.predict(X_test)

# Model Performance
mae = metrics.mean_absolute_error(y_test, y_pred_dTree)
mse = metrics.mean_squared_error(y_test, y_pred_dTree)
rmse = np.sqrt(mse) # or mse**(0.5)
r2 = metrics.r2_score(y_test, y_pred_dTree)

print("Results")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results
# MAE: 0.17566020975969002
# MSE: 0.23734446557546943
# RMSE: 0.48718011615363516
# R-Squared: 0.9999565855160756

# %%
# Plotting
plt.scatter(y_test, y_pred_dTree)
plt.xlabel('y_test')
plt.ylabel('y_pred_dTree')
plt.title('Actual Values vs Predicted Values')
plt.show()

# %% [markdown]
# K-NN

# %%
knn = KNeighborsRegressor(n_neighbors=2)

# Model Training
knn.fit(X_train,y_train)

# Model Prediction
y_pred_knn = knn.predict(X_test)

# Model Performance
mae = metrics.mean_absolute_error(y_test, y_pred_dTree)
mse = metrics.mean_squared_error(y_test, y_pred_dTree)
rmse = np.sqrt(mse) # or mse**(0.5)
r2 = metrics.r2_score(y_test, y_pred_dTree)

print("Results:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results:
# MAE: 0.17566020975969002
# MSE: 0.23734446557546943
# RMSE: 0.48718011615363516
# R-Squared: 0.9999565855160756

# %%
# Plotting
plt.scatter(y_test, y_pred_knn)
plt.xlabel('y_test')
plt.ylabel('y_pred_knn')
plt.title('Actual Values vs Predicted Values')
plt.show()

# %% [markdown]
# # Ensemble Model (Bagging and Boosting)

# %% [markdown]
# Random Forest

# %%
rf_reg=RandomForestRegressor(n_estimators=100)

# Model Training
rf_reg.fit(X_train,y_train)

# Model Prediction
prediction=rf_reg.predict(X_test)

# Model Performance
mae = metrics.mean_absolute_error(y_test, prediction)
mse = metrics.mean_squared_error(y_test, prediction)
rmse = np.sqrt(mse) # or mse**(0.5)
r2 = metrics.r2_score(y_test, prediction)

print("Results:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results:
# MAE: 0.15035460486894767
# MSE: 0.15862555426923702
# RMSE: 0.39827823725284944
# R-Squared: 0.9999709845917024

# %%
# Plotting
plt.scatter(y_test, prediction)
plt.xlabel('y_test')
plt.ylabel('prediction')
plt.title('Actual Values vs Predicted Values')
plt.show()

# %% [markdown]
# # LSTM model

# %%
#Load the dataset
stock2 = pd.read_csv('/content/msft-daily-max.csv')
stock2['Date'] = pd.to_datetime(stock2['Date'])

# %%
print(f'DataFrame contains stock prices between {stock2.Date.min()} {stock2.Date.max()}')
print(f'Total days = {(stock2.Date.max() - stock2.Date.min()).days} days')
# Out:
# DataFrame contains stock prices between 1986-03-13 00:00:00 2023-06-20 00:00:00
# Total days = 13613 days

# %%
stock2.head()
# Out:
#         Date      Open      High       Low     Close      Volume  Adj Close
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222  1031788800   0.060524
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   308160000   0.062686
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   133171200   0.063767
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826    67766400   0.062145
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090    47894400   0.061065

# %%
# Outlier detection

q1, q3 = np.percentile(stock2['Open'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock2[(stock2['Open'] >= lower_bound)
                & (stock2['Open'] <= upper_bound)]

q1, q3 = np.percentile(stock2['High'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock2[(stock2['High'] >= lower_bound)
                & (stock2['High'] <= upper_bound)]

q1, q3 = np.percentile(stock2['Low'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock2[(stock2['Low'] >= lower_bound)
                & (stock2['Low'] <= upper_bound)]

q1, q3 = np.percentile(stock2['Close'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock2[(stock2['Close'] >= lower_bound)
                & (stock2['Close'] <= upper_bound)]

q1, q3 = np.percentile(stock2['Adj Close'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock2[(stock2['Adj Close'] >= lower_bound)
                & (stock2['Adj Close'] <= upper_bound)]

q1, q3 = np.percentile(stock2['Volume'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = stock2[(stock2['Volume'] >= lower_bound)
                & (stock2['Volume'] <= upper_bound)]

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(clean_data['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column
data = clean_data.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 8575

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[2.74360175e-05],
#        [2.24476484e-05],
#        [1.49650989e-05],
#        ...,
#        [1.00000000e+00],
#        [9.83419948e-01],
#        [9.71121444e-01]])

# %%
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()

# Convert the x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([2.74360175e-05, 2.24476484e-05, 1.49650989e-05, 7.48254945e-06,
#        0.00000000e+00, 4.98836630e-06, 1.24709158e-05, 1.74592821e-05,
#        1.49650989e-05, 1.24709158e-05, 1.49650989e-05, 1.74592821e-05,
#        1.74592821e-05, 1.24709158e-05, 1.49650989e-05, 1.99534652e-05,
#        2.24476484e-05, 2.74360175e-05, 2.99302007e-05, 2.99302007e-05,
#        3.99098010e-05, 4.24039870e-05, 3.24272516e-05, 3.24272516e-05,
#        2.74360175e-05, 2.86830976e-05, 5.73690859e-05, 7.73254218e-05,
#        7.98196049e-05, 6.98400046e-05, 6.23574522e-05, 5.73690859e-05,
#        5.73690859e-05, 5.48749028e-05, 5.73690859e-05, 5.73690859e-05,
#        5.98632691e-05, 5.73690859e-05, 5.98632691e-05, 6.23574522e-05,
#        5.98632691e-05, 5.98632691e-05, 6.23574522e-05, 5.73690859e-05,
#        5.48749028e-05, 4.98865365e-05, 4.98865365e-05, 4.98865365e-05,
#        5.98632691e-05, 6.98400046e-05, 7.73254218e-05, 8.97963404e-05,
#        7.98196049e-05, 7.98196049e-05, 7.73254218e-05, 8.23137881e-05,
#        8.23137881e-05, 6.73458185e-05, 6.73458185e-05, 6.73458185e-05])]
# [5.487490279154644e-05]
#
# [array([2.74360175e-05, 2.24476484e-05, 1.49650989e-05, 7.48254945e-06,
#        0.00000000e+00, 4.98836630e-06, 1.24709158e-05, 1.74592821e-05,
#        1.49650989e-05, 1.24709158e-05, 1.49650989e-05, 1.74592821e-05,
#        1.74592821e-05, 1.24709158e-05, 1.49650989e-05, 1.99534652e-05,
#        2.24476484e-05, 2.74360175e-05, 2.99302007e-05, 2.99302007e-05,
#        3.99098010e-05, 4.24039870e-05, 3.24272516e-05, 3.24272516e-05,
#        2.74360175e-05, 2.86830976e-05, 5.73690859e-05, 7.73254218e-05,
#        7.98196049e-05, 6.98400046e-05, 6.23574522e-05, 5.73690859e-05,
#        5.73690859e-05, 5.48749028e-05, 5.73690859e-05, 5.73690859e-05,
#        5.98632691e-05, 5.73690859e-05, 5.98632691e-05, 6.23574522e-05,
#        5.98632691e-05, 5.98632691e-05, 6.23574522e-05, 5.73690859e-05,
#        5.48749028e-05, 4.98865365e-05, 4.98865365e-05, 4.98865365e-05,
#        5.98632691e-05, 6.98400046e-05, 7.73254218e-05, 8.97963404e-05,
#        7.98196049e-05, 7.98196049e-05, 7.73254218e-05, 8.23137881e-05,
#        8.23137881e-05, 6.73458185e-05, 6.73458185e-05, 6.73458185e-05]), array([2.24476484e-05, 1.49650989e-05, 7.48254945e-06, 0.00000000e+00,
#        4.98836630e-06, 1.24709158e-05, 1.74592821e-05, 1.49650989e-05,
#        1.24709158e-05, 1.49650989e-05, 1.74592821e-05, 1.74592821e-05,
#        1.24709158e-05, 1.49650989e-05, 1.99534652e-05, 2.24476484e-05,
#        2.74360175e-05, 2.99302007e-05, 2.99302007e-05, 3.99098010e-05,
#        4.24039870e-05, 3.24272516e-05, 3.24272516e-05, 2.74360175e-05,
#        2.86830976e-05, 5.73690859e-05, 7.73254218e-05, 7.98196049e-05,
#        6.98400046e-05, 6.23574522e-05, 5.73690859e-05, 5.73690859e-05,
#        5.48749028e-05, 5.73690859e-05, 5.73690859e-05, 5.98632691e-05,
#        5.73690859e-05, 5.98632691e-05, 6.23574522e-05, 5.98632691e-05,
#        5.98632691e-05, 6.23574522e-05, 5.73690859e-05, 5.48749028e-05,
#        4.98865365e-05, 4.98865365e-05, 4.98865365e-05, 5.98632691e-05,
#        6.98400046e-05, 7.73254218e-05, 8.97963404e-05, 7.98196049e-05,
#        7.98196049e-05, 7.73254218e-05, 8.23137881e-05, 8.23137881e-05,
#        6.73458185e-05, 6.73458185e-05, 6.73458185e-05, 5.48749028e-05])]
# [5.487490279154644e-05, 5.487490279154644e-05]

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 8515/8515 [==============================] - 487s 56ms/step - loss: 6.5804e-04

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 15/15 [==============================] - 2s 33ms/step
# 22.495062956550203

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
valid
# Out:
#            Close  Predictions
# 8942  301.149994   278.738922
# 8943  301.140015   278.655823
# 8944  300.179993   278.530121
# 8945  300.209992   278.219177
# 8946  297.250000   277.923859
# ...          ...          ...
# 9388  334.290008   302.146149
# 9389  337.339996   303.433319
# 9390  348.100006   305.405212
# 9391  342.329987   309.357300
# 9392  338.049988   311.880615
#
# [451 rows x 2 columns]
